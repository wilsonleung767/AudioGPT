# %%
from langchain.llms import OpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain
from langchain import LLMChain, PromptTemplate

# %%
import os
os.environ['OPENAI_API_KEY'] = "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"

# %%
def split_text_to_list(filename, chunk_size):
    with open(filename, "r") as file:
        text = file.readline()

    splitted_text_list = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    return splitted_text_list
texts = split_text_to_list("script/cutVer.txt", 2500)

# %%
llm = OpenAI(model_name="gpt-3.5-turbo", temperature= 0.6 , max_tokens=256)

template = """You are a helpful assistant that can help me summerize the content of a podcast script. Do not response to me until I ask you to give a summary!
{chat_history}
Human: {human_input}
Chatbot:"""

prompt = PromptTemplate(
    input_variables=["chat_history", "human_input"], 
    template= template
)
memory = ConversationBufferMemory(memory_key="chat_history")


llm_chain = LLMChain(
    llm= llm, 
    prompt=prompt, 
    verbose=True, 
    memory=memory,
)

# %%
for text_segment in texts:
    llm_chain.predict(human_input= text_segment)

llm_chain.predict(human_input= "Now, summarize the script in point forms, keep them detailed")
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# You are a helpful assistant that can help me summerize the content of a podcast script. Do not response to me until I ask you to give a summary!
#
# ...
